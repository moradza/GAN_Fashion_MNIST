# %% [markdown]
# # Generative Adversarial Network for Fashion-MNIST
#
# Here, a generative adversarial network (GAN) is trained on the Fashion-MNIST dataset. Objective of the GAN is to generate new fashion clothes.
# GANs were developed by Ian Goodfellow et al. in 2014 ([see](https://arxiv.org/abs/1406.2661)).
# GANs relies on the idea to have two networks, a generator $G$ and a discrimininator $D$, competing agiant each other. While $G$ tries to create fake data, the discriminator task is to determine whether the data passed to it is drawn from real data or it is generated by $G$. It is, in fact, similar to a two-party game, in which $G$ and $D$ are improving their performance throguh competition between each other. The value function for GAN can be written as,
#
# $\min \max V(D, G) = \mathrm{E}_{x\sim p_{data(x)}} [\log D(x)] + \mathrm{E}_{z\sim p_z(z)} [ \log (1-D(G(z))]$
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes fake data to pass to the discriminator. The discriminator also sees real data and predicts if the data it's received is real or fake. The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real data. And the discriminator is trained to figure out which data is real and which is fake. What ends up happening is that the generator learns to make data that is indistiguishable from real data to the discriminator.
#
# ![GAN diagram](assets/gan_diagram.png)
#
# The general structure of a GAN is shown in the diagram above, using Fashion-MNIST images as data. The latent sample is a random vector the generator uses to contruct it's fake images. As the generator learns through training, it figures out how to map these random vectors to recognizable images that can foold the discriminator.
#
# The output of the discriminator is a sigmoid function, where 0 indicates a fake image and 1 indicates an real image. If you're interested only in generating new images, you can throw out the discriminator after training. The code is written in TensorFlow.

# %%
# %matplotlib inline

import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
data = input_data.read_data_sets('Fashion_MNIST_data')
import mnist_reader
X_train, y_train = mnist_reader.load_mnist('Fashion_MNIST_data', kind='train')
X_test, y_test = mnist_reader.load_mnist('Fashion_MNIST_data', kind='t10k')
# Out:
# Extracting Fashion_MNIST_data\train-images-idx3-ubyte.gz
# Extracting Fashion_MNIST_data\train-labels-idx1-ubyte.gz
# Extracting Fashion_MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting Fashion_MNIST_data\t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Real Data Visulaization
#
# See Fashion dataset samples!

# %%
fig, ax = plt.subplots(figsize=(1, 1))
img = X_train[308]

plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %% [markdown]
# ##  GAN Inputs
#
# Two sets of input should be created for the network. Inputs of the generator, which are random, are called inputs_z. Inputs of discriminator, which are fashion-MNIST data set, are called inputs_real.

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, (None, real_dim), name='input_real') 
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    
    return inputs_real, inputs_z

# %% [markdown]
# #  GAN Network
#
# The GAN network is shown in figure below.
#
# ![GAN Network](assets/gan_network.png)
#
#
# ## Generator Network
# The generator network is created here with two hidden layers using leaky ReLU to aviod gradient vanishing and in order to make sure that it has enough capacity for function approximation.
#
# ### TensorFlow Variable Scope
#
# During training, the generator and discriminator are optimized seperately. Furthermore, it is possible to use the reuse keyword in order to sample during training or after training.
#
#
# ### Action Function
# #### Leaky ReLU
# The leaky ReLU is defined as follow,
#
# $$
# f(x) = max(\alpha \times x, x)
# $$
# where $x$ is the input. If it is positive, the ouput is $x$ , otherwise, it is $\alpha \times x$.
#
# #### Tanh
# According to previous studies, the generator has the best performance with $tanh$ for the its output.
#
# ## Discriminator Network
#
# The only difference between the discriminator and generator networks is the ouput layer. The discriminator uses sigmoid activation instead of $tanh$.
# #### Sigmoid
# The Sigmoid function is defined as,
# $$
#     \sigma (x) = \frac{1}{1+\exp(-x)}
# $$

# %%
def generator(z, out_dim, n_units=128, reuse=False, alpha=0.01):
    with tf.variable_scope('generator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation=None)
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        h2 = tf.layers.dense(h1, n_units * 2 , activation=None)
        h2 = tf.maximum(alpha * h2, h2)
        # Logits and tanh output
        logits = tf.layers.dense(h2, out_dim, activation=None)
        out = tf.tanh(logits)
        
        return out

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    with tf.variable_scope('discriminator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation=None)
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        h2 = tf.layers.dense(h1, n_units / 2, activation=None)
        h2 = tf.maximum(alpha * h2, h2)
        
        logits = tf.layers.dense(h2, 1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %% [markdown]
# ## Hyperparameters

# %%
# Size of input image to discriminator
input_size = 784
# Size of latent vector to generator
z_size = 128
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 256
d_hidden_size = 256
# Leak factor for leaky ReLU
alpha = 0.01
# Smoothing 
smooth = 0.1

# %% [markdown]
# ## Build network
#
# The networks for both $G$ and $D$ are created here. Furthermore, two networks are built for $D$, one for real input and one for generated data by $G$. As the weights should be the same for both real and generated inputs,the reuse keyword is used. For the generated data, it is ouput of $G$, here defined as `g_model`.
# Therefore, the real input of the discriminator is `discriminator(input_real)` while the fake discriminator is `discriminator(g_model, reuse=True)`.

# %%
tf.reset_default_graph()
#  Input placeholders are created
input_real, input_z = model_inputs(input_size, z_size)

# The generator network is created
g_model = generator(input_z, input_size, n_units=g_hidden_size, alpha=alpha)

# The discriminator networks are created one for real input and one for generated input
d_model_real, d_logits_real = discriminator(input_real, n_units=d_hidden_size, alpha=alpha)
d_model_fake, d_logits_fake = discriminator(g_model, reuse=True, n_units=d_hidden_size, alpha=alpha)

# %% [markdown]
# ##  $D$ and $G$ Losses
#
# Now we need to calculate the losses, which is a little tricky. For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_loss_real + d_loss_fake`. The losses will by sigmoid cross-entropys, which we can get with `tf.nn.sigmoid_cross_entropy_with_logits`. We'll also wrap that in `tf.reduce_mean` to get the mean for all the images in the batch. So the losses will look something like
#
# ```python
# tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=labels))
# ```
#
# For the real image logits, we'll use `d_logits_real` which we got from the discriminator in the cell above. For the labels, we want them to be all ones, since these are all real images. To help the discriminator generalize better, the labels are reduced a bit from 1.0 to 0.9, for example,  using the parameter `smooth`. This is known as label smoothing, typically used with classifiers to improve performance. In TensorFlow, it looks something like `labels = tf.ones_like(tensor) * (1 - smooth)`
#
# The discriminator loss for the fake data is similar. The logits are `d_logits_fake`, which we got from passing the generator output to the discriminator. These fake logits are used with labels of all zeros. Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# Finally, the generator losses are using `d_logits_fake`, the fake image logits. But, now the labels are all ones. The generator is trying to fool the discriminator, so it wants to discriminator to output ones for fake images.

# %%
# Calculate losses
d_loss_real = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                          labels=tf.ones_like(d_logits_real) * (1 - smooth)))
d_loss_fake = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                          labels=tf.zeros_like(d_logits_real)))
d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(
             tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                     labels=tf.ones_like(d_logits_fake)))

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So we need to get the variables for each part build optimizers for the two parts. To get all the trainable variables, we use `tf.trainable_variables()`. This creates a list of all the variables we've defined in our graph.
#
# For the generator optimizer, we only want to generator variables. Our past selves were nice and used a variable scope to start all of our generator variable names with `generator`. So, we just need to iterate through the list from `tf.trainable_variables()` and keep variables to start with `generator`. Each variable object has an attribute `name` which holds the name of the variable as a string (`var.name == 'weights_0'` for instance).
#
# We can do something similar with the discriminator. All the variables in the discriminator start with `discriminator`.
#
# Then, in the optimizer we pass the variable lists to `var_list` in the `minimize` method. This tells the optimizer to only update the listed variables. Something like `tf.train.AdamOptimizer().minimize(loss, var_list=var_list)` will only train the variables in `var_list`.

# %%
# Optimizers
learning_rate = 0.0005

# Get the trainable_variables, split into G and D parts
t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator')]
d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %% [markdown]
# ## Training

# %%
batch_size = 128
epochs = 500
samples = []
losses = []
# Only save generator variables
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(data.train.num_examples//batch_size):
            batch = data.train.next_batch(batch_size)
            
            # Get images, reshape and rescale to pass to D
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size)) # modified
            #batch_z = batch_images#batch[0].reshape((z_size, 784)) #modified
            #batch_z = 2 * batch_z - 1
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
        losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/500... Discriminator Loss: 0.4344... Generator Loss: 3.0002
# Epoch 2/500... Discriminator Loss: 0.3922... Generator Loss: 3.6281
# Epoch 3/500... Discriminator Loss: 0.3677... Generator Loss: 5.3941
# Epoch 4/500... Discriminator Loss: 0.4486... Generator Loss: 2.8223
# Epoch 5/500... Discriminator Loss: 0.4554... Generator Loss: 4.1866
# Epoch 6/500... Discriminator Loss: 0.7333... Generator Loss: 2.6787
# Epoch 7/500... Discriminator Loss: 0.5301... Generator Loss: 3.3337
# Epoch 8/500... Discriminator Loss: 0.5834... Generator Loss: 3.9994
# Epoch 9/500... Discriminator Loss: 0.5863... Generator Loss: 2.3615
# Epoch 10/500... Discriminator Loss: 0.5914... Generator Loss: 3.6337
# Epoch 11/500... Discriminator Loss: 0.6542... Generator Loss: 3.0880
# Epoch 12/500... Discriminator Loss: 0.7239... Generator Loss: 2.2960
# Epoch 13/500... Discriminator Loss: 0.6077... Generator Loss: 2.5002
# Epoch 14/500... Discriminator Loss: 0.5101... Generator Loss: 3.3139
# Epoch 15/500... Discriminator Loss: 0.6477... Generator Loss: 3.0135
# Epoch 16/500... Discriminator Loss: 0.7634... Generator Loss: 2.3081
# Epoch 17/500... Discriminator Loss: 0.7358... Generator Loss: 2.3895
# Epoch 18/500... Discriminator Loss: 0.7812... Generator Loss: 1.7263
# Epoch 19/500... Discriminator Loss: 0.5732... Generator Loss: 2.8036
# Epoch 20/500... Discriminator Loss: 0.7698... Generator Loss: 1.9745
# Epoch 21/500... Discriminator Loss: 0.9153... Generator Loss: 1.9438
# Epoch 22/500... Discriminator Loss: 0.7304... Generator Loss: 2.1205
# Epoch 23/500... Discriminator Loss: 1.1082... Generator Loss: 1.6292
# Epoch 24/500... Discriminator Loss: 0.9791... Generator Loss: 1.6437
# Epoch 25/500... Discriminator Loss: 0.7137... Generator Loss: 2.1565
# Epoch 26/500... Discriminator Loss: 0.8315... Generator Loss: 1.8993
# Epoch 27/500... Discriminator Loss: 0.7935... Generator Loss: 1.8185
# Epoch 28/500... Discriminator Loss: 0.8528... Generator Loss: 1.6870
# Epoch 29/500... Discriminator Loss: 0.8896... Generator Loss: 2.0816
# Epoch 30/500... Discriminator Loss: 0.9517... Generator Loss: 1.7972
# Epoch 31/500... Discriminator Loss: 1.3526... Generator Loss: 1.2900
# Epoch 32/500... Discriminator Loss: 0.9532... Generator Loss: 2.2216
# Epoch 33/500... Discriminator Loss: 0.7717... Generator Loss: 2.0217
# Epoch 34/500... Discriminator Loss: 0.7775... Generator Loss: 2.0651
# Epoch 35/500... Discriminator Loss: 0.9037... Generator Loss: 1.7164
# Epoch 36/500... Discriminator Loss: 1.0208... Generator Loss: 1.6907
# Epoch 37/500... Discriminator Loss: 1.0640... Generator Loss: 1.3978
# Epoch 38/500... Discriminator Loss: 1.0204... Generator Loss: 1.4980
# Epoch 39/500... Discriminator Loss: 0.9616... Generator Loss: 1.7131
# Epoch 40/500... Discriminator Loss: 0.8417... Generator Loss: 1.7288
# Epoch 41/500... Discriminator Loss: 0.8770... Generator Loss: 1.8408
# Epoch 42/500... Discriminator Loss: 1.0204... Generator Loss: 1.4367
# Epoch 43/500... Discriminator Loss: 0.9194... Generator Loss: 1.7268
# Epoch 44/500... Discriminator Loss: 1.2046... Generator Loss: 1.4944
# Epoch 45/500... Discriminator Loss: 0.8340... Generator Loss: 1.6306
# Epoch 46/500... Discriminator Loss: 1.0536... Generator Loss: 1.4101
# Epoch 47/500... Discriminator Loss: 1.0345... Generator Loss: 1.6369
# Epoch 48/500... Discriminator Loss: 1.1051... Generator Loss: 1.3958
# Epoch 49/500... Discriminator Loss: 1.1182... Generator Loss: 1.2766
# Epoch 50/500... Discriminator Loss: 1.2767... Generator Loss: 1.4754
# Epoch 51/500... Discriminator Loss: 1.1208... Generator Loss: 1.4164
# Epoch 52/500... Discriminator Loss: 0.9912... Generator Loss: 1.5412
# Epoch 53/500... Discriminator Loss: 0.9245... Generator Loss: 1.6792
# Epoch 54/500... Discriminator Loss: 1.0934... Generator Loss: 1.4231
# Epoch 55/500... Discriminator Loss: 1.6076... Generator Loss: 1.1205
# Epoch 56/500... Discriminator Loss: 1.1962... Generator Loss: 1.1736
# Epoch 57/500... Discriminator Loss: 0.9784... Generator Loss: 1.3444
# Epoch 58/500... Discriminator Loss: 1.0900... Generator Loss: 1.4973
# Epoch 59/500... Discriminator Loss: 1.1678... Generator Loss: 1.6954
# Epoch 60/500... Discriminator Loss: 1.2511... Generator Loss: 1.2269
# Epoch 61/500... Discriminator Loss: 1.0602... Generator Loss: 1.5271
# Epoch 62/500... Discriminator Loss: 1.1436... Generator Loss: 1.3470
# Epoch 63/500... Discriminator Loss: 1.3361... Generator Loss: 1.1643
# Epoch 64/500... Discriminator Loss: 1.1139... Generator Loss: 1.2682
# Epoch 65/500... Discriminator Loss: 1.0237... Generator Loss: 1.3105
# Epoch 66/500... Discriminator Loss: 1.3005... Generator Loss: 1.1756
# Epoch 67/500... Discriminator Loss: 1.0958... Generator Loss: 1.3745
# Epoch 68/500... Discriminator Loss: 0.9741... Generator Loss: 1.4743
# Epoch 69/500... Discriminator Loss: 1.1699... Generator Loss: 1.3962
# Epoch 70/500... Discriminator Loss: 1.0793... Generator Loss: 1.2084
# Epoch 71/500... Discriminator Loss: 1.2063... Generator Loss: 1.3290
# Epoch 72/500... Discriminator Loss: 0.9831... Generator Loss: 1.1877
# Epoch 73/500... Discriminator Loss: 0.9731... Generator Loss: 1.4073
# Epoch 74/500... Discriminator Loss: 1.0296... Generator Loss: 1.3826
# Epoch 75/500... Discriminator Loss: 0.9997... Generator Loss: 1.4986
# Epoch 76/500... Discriminator Loss: 1.5213... Generator Loss: 1.2600
# Epoch 77/500... Discriminator Loss: 1.1914... Generator Loss: 1.4769
# Epoch 78/500... Discriminator Loss: 1.1012... Generator Loss: 1.1848
# Epoch 79/500... Discriminator Loss: 1.1819... Generator Loss: 1.1916
# Epoch 80/500... Discriminator Loss: 1.0783... Generator Loss: 1.2246
# Epoch 81/500... Discriminator Loss: 1.0792... Generator Loss: 1.4321
# Epoch 82/500... Discriminator Loss: 1.1272... Generator Loss: 1.5240
# Epoch 83/500... Discriminator Loss: 1.2127... Generator Loss: 1.0759
# Epoch 84/500... Discriminator Loss: 1.2028... Generator Loss: 1.2386
# Epoch 85/500... Discriminator Loss: 1.1776... Generator Loss: 1.1275
# Epoch 86/500... Discriminator Loss: 1.2064... Generator Loss: 1.2332
# Epoch 87/500... Discriminator Loss: 1.0497... Generator Loss: 1.2805
# Epoch 88/500... Discriminator Loss: 1.4966... Generator Loss: 1.0105
# Epoch 89/500... Discriminator Loss: 1.1376... Generator Loss: 1.2729
# Epoch 90/500... Discriminator Loss: 1.1661... Generator Loss: 1.1489
# Epoch 91/500... Discriminator Loss: 1.1898... Generator Loss: 1.0812
# Epoch 92/500... Discriminator Loss: 1.2318... Generator Loss: 1.1055
# Epoch 93/500... Discriminator Loss: 1.3504... Generator Loss: 1.0196
# Epoch 94/500... Discriminator Loss: 1.3289... Generator Loss: 0.9721
# Epoch 95/500... Discriminator Loss: 1.2382... Generator Loss: 1.6154
# Epoch 96/500... Discriminator Loss: 1.3317... Generator Loss: 1.0506
# Epoch 97/500... Discriminator Loss: 1.3896... Generator Loss: 1.0175
# Epoch 98/500... Discriminator Loss: 0.9781... Generator Loss: 1.4952
# Epoch 99/500... Discriminator Loss: 1.1310... Generator Loss: 1.6898
# Epoch 100/500... Discriminator Loss: 1.0845... Generator Loss: 1.2735
# Epoch 101/500... Discriminator Loss: 1.2232... Generator Loss: 1.0431
# Epoch 102/500... Discriminator Loss: 1.3278... Generator Loss: 1.0915
# Epoch 103/500... Discriminator Loss: 1.1752... Generator Loss: 1.1076
# Epoch 104/500... Discriminator Loss: 1.2333... Generator Loss: 1.0450
# Epoch 105/500... Discriminator Loss: 1.3507... Generator Loss: 0.9227
# Epoch 106/500... Discriminator Loss: 1.0809... Generator Loss: 1.1170
# Epoch 107/500... Discriminator Loss: 1.3060... Generator Loss: 1.0244
# Epoch 108/500... Discriminator Loss: 1.4358... Generator Loss: 1.1484
# Epoch 109/500... Discriminator Loss: 1.3757... Generator Loss: 1.1100
# Epoch 110/500... Discriminator Loss: 1.1289... Generator Loss: 1.3270
# Epoch 111/500... Discriminator Loss: 1.4413... Generator Loss: 1.0630
# Epoch 112/500... Discriminator Loss: 1.3665... Generator Loss: 1.0547
# Epoch 113/500... Discriminator Loss: 1.3646... Generator Loss: 0.9403
# Epoch 114/500... Discriminator Loss: 1.4107... Generator Loss: 1.0380
# Epoch 115/500... Discriminator Loss: 1.3373... Generator Loss: 0.8723
# Epoch 116/500... Discriminator Loss: 1.2487... Generator Loss: 1.1091
# Epoch 117/500... Discriminator Loss: 1.3136... Generator Loss: 1.1104
# Epoch 118/500... Discriminator Loss: 1.3437... Generator Loss: 1.0016
# Epoch 119/500... Discriminator Loss: 1.2370... Generator Loss: 1.2205
# Epoch 120/500... Discriminator Loss: 1.1203... Generator Loss: 1.6000
# Epoch 121/500... Discriminator Loss: 1.7595... Generator Loss: 1.6107
# Epoch 122/500... Discriminator Loss: 1.4787... Generator Loss: 1.4951
# Epoch 123/500... Discriminator Loss: 1.2488... Generator Loss: 1.2007
# Epoch 124/500... Discriminator Loss: 1.2395... Generator Loss: 1.1605
# Epoch 125/500... Discriminator Loss: 1.2018... Generator Loss: 1.1469
# Epoch 126/500... Discriminator Loss: 1.2346... Generator Loss: 1.1115
# Epoch 127/500... Discriminator Loss: 1.2203... Generator Loss: 1.2344
# Epoch 128/500... Discriminator Loss: 1.4229... Generator Loss: 0.9619
# Epoch 129/500... Discriminator Loss: 1.3224... Generator Loss: 1.1920
# Epoch 130/500... Discriminator Loss: 1.4212... Generator Loss: 0.8813
# Epoch 131/500... Discriminator Loss: 1.1980... Generator Loss: 1.1869
# Epoch 132/500... Discriminator Loss: 1.2508... Generator Loss: 1.1144
# Epoch 133/500... Discriminator Loss: 1.1631... Generator Loss: 1.2905
# Epoch 134/500... Discriminator Loss: 1.2748... Generator Loss: 0.9755
# Epoch 135/500... Discriminator Loss: 1.3077... Generator Loss: 0.9142
# Epoch 136/500... Discriminator Loss: 1.0237... Generator Loss: 1.4770
# Epoch 137/500... Discriminator Loss: 1.6163... Generator Loss: 1.3153
# Epoch 138/500... Discriminator Loss: 1.1787... Generator Loss: 1.1281
# Epoch 139/500... Discriminator Loss: 1.4805... Generator Loss: 0.8525
# Epoch 140/500... Discriminator Loss: 1.1631... Generator Loss: 1.2280
# Epoch 141/500... Discriminator Loss: 1.2380... Generator Loss: 1.0068
# Epoch 142/500... Discriminator Loss: 1.2343... Generator Loss: 1.2165
# Epoch 143/500... Discriminator Loss: 1.2954... Generator Loss: 1.0911
# Epoch 144/500... Discriminator Loss: 1.2820... Generator Loss: 1.0026
# Epoch 145/500... Discriminator Loss: 1.3014... Generator Loss: 0.9277
# Epoch 146/500... Discriminator Loss: 1.2774... Generator Loss: 1.1735
# Epoch 147/500... Discriminator Loss: 1.1632... Generator Loss: 1.3042
# Epoch 148/500... Discriminator Loss: 1.1464... Generator Loss: 1.0769
# Epoch 149/500... Discriminator Loss: 1.3047... Generator Loss: 0.9897
# Epoch 150/500... Discriminator Loss: 1.3826... Generator Loss: 1.1122
# Epoch 151/500... Discriminator Loss: 1.2817... Generator Loss: 0.9799
# Epoch 152/500... Discriminator Loss: 1.1702... Generator Loss: 1.3753
# Epoch 153/500... Discriminator Loss: 1.0488... Generator Loss: 1.4411
# Epoch 154/500... Discriminator Loss: 1.5737... Generator Loss: 0.9248
# Epoch 155/500... Discriminator Loss: 1.2069... Generator Loss: 1.1224
# Epoch 156/500... Discriminator Loss: 1.3281... Generator Loss: 0.9719
# Epoch 157/500... Discriminator Loss: 1.2740... Generator Loss: 0.9984
# Epoch 158/500... Discriminator Loss: 1.3161... Generator Loss: 1.0186
# Epoch 159/500... Discriminator Loss: 1.2484... Generator Loss: 1.0258
# Epoch 160/500... Discriminator Loss: 1.2842... Generator Loss: 1.0810
# Epoch 161/500... Discriminator Loss: 1.1949... Generator Loss: 1.0791
# Epoch 162/500... Discriminator Loss: 1.5185... Generator Loss: 1.0933
# Epoch 163/500... Discriminator Loss: 1.1030... Generator Loss: 1.4110
# Epoch 164/500... Discriminator Loss: 1.3666... Generator Loss: 1.2847
# Epoch 165/500... Discriminator Loss: 1.4102... Generator Loss: 1.0148
# Epoch 166/500... Discriminator Loss: 1.4308... Generator Loss: 0.9402
# Epoch 167/500... Discriminator Loss: 1.3724... Generator Loss: 1.0248
# Epoch 168/500... Discriminator Loss: 1.3786... Generator Loss: 1.0046
# Epoch 169/500... Discriminator Loss: 1.4978... Generator Loss: 0.8929
# Epoch 170/500... Discriminator Loss: 1.3242... Generator Loss: 0.9903
# Epoch 171/500... Discriminator Loss: 1.3481... Generator Loss: 0.8676
# Epoch 172/500... Discriminator Loss: 1.4125... Generator Loss: 0.8134
# Epoch 173/500... Discriminator Loss: 1.3283... Generator Loss: 1.1584
# Epoch 174/500... Discriminator Loss: 1.1592... Generator Loss: 1.1919
# Epoch 175/500... Discriminator Loss: 1.2088... Generator Loss: 1.1665
# Epoch 176/500... Discriminator Loss: 1.2431... Generator Loss: 0.9213
# Epoch 177/500... Discriminator Loss: 1.4605... Generator Loss: 1.0070
# Epoch 178/500... Discriminator Loss: 1.6555... Generator Loss: 0.7940
# Epoch 179/500... Discriminator Loss: 1.3653... Generator Loss: 1.0056
# Epoch 180/500... Discriminator Loss: 1.2845... Generator Loss: 1.1931
# Epoch 181/500... Discriminator Loss: 1.0984... Generator Loss: 1.2955
# Epoch 182/500... Discriminator Loss: 1.1622... Generator Loss: 1.2454
# Epoch 183/500... Discriminator Loss: 1.2044... Generator Loss: 1.1242
# Epoch 184/500... Discriminator Loss: 1.2632... Generator Loss: 1.1066
# Epoch 185/500... Discriminator Loss: 1.4478... Generator Loss: 1.0629
# Epoch 186/500... Discriminator Loss: 1.3576... Generator Loss: 0.9845
# Epoch 187/500... Discriminator Loss: 1.3084... Generator Loss: 0.9956
# Epoch 188/500... Discriminator Loss: 1.5125... Generator Loss: 0.9359
# Epoch 189/500... Discriminator Loss: 1.3232... Generator Loss: 0.9836
# Epoch 190/500... Discriminator Loss: 1.2839... Generator Loss: 0.9864
# Epoch 191/500... Discriminator Loss: 1.2858... Generator Loss: 0.8902
# Epoch 192/500... Discriminator Loss: 1.4465... Generator Loss: 0.7905
# Epoch 193/500... Discriminator Loss: 1.4997... Generator Loss: 1.0748
# Epoch 194/500... Discriminator Loss: 1.1560... Generator Loss: 1.3133
# Epoch 195/500... Discriminator Loss: 1.2266... Generator Loss: 1.2288
# Epoch 196/500... Discriminator Loss: 1.1572... Generator Loss: 1.2646
# Epoch 197/500... Discriminator Loss: 1.3422... Generator Loss: 0.9626
# Epoch 198/500... Discriminator Loss: 1.0726... Generator Loss: 1.2657
# Epoch 199/500... Discriminator Loss: 1.2854... Generator Loss: 1.0330
# Epoch 200/500... Discriminator Loss: 1.1789... Generator Loss: 1.1619
# Epoch 201/500... Discriminator Loss: 1.3296... Generator Loss: 1.1651
# Epoch 202/500... Discriminator Loss: 1.2385... Generator Loss: 1.0883
# Epoch 203/500... Discriminator Loss: 1.3021... Generator Loss: 1.1220
# Epoch 204/500... Discriminator Loss: 1.1988... Generator Loss: 1.0960
# Epoch 205/500... Discriminator Loss: 1.2720... Generator Loss: 1.1046
# Epoch 206/500... Discriminator Loss: 1.2453... Generator Loss: 1.0333
# Epoch 207/500... Discriminator Loss: 1.2097... Generator Loss: 0.9874
# Epoch 208/500... Discriminator Loss: 1.2187... Generator Loss: 1.0475
# Epoch 209/500... Discriminator Loss: 1.2746... Generator Loss: 0.9738
# Epoch 210/500... Discriminator Loss: 1.4537... Generator Loss: 0.8747
# Epoch 211/500... Discriminator Loss: 1.1918... Generator Loss: 1.1107
# Epoch 212/500... Discriminator Loss: 1.3166... Generator Loss: 0.9989
# Epoch 213/500... Discriminator Loss: 1.1348... Generator Loss: 1.2248
# Epoch 214/500... Discriminator Loss: 1.2357... Generator Loss: 1.1671
# Epoch 215/500... Discriminator Loss: 1.3110... Generator Loss: 1.2706
# Epoch 216/500... Discriminator Loss: 1.5874... Generator Loss: 1.0852
# Epoch 217/500... Discriminator Loss: 1.6195... Generator Loss: 0.9080
# Epoch 218/500... Discriminator Loss: 1.3086... Generator Loss: 0.9959
# Epoch 219/500... Discriminator Loss: 1.1018... Generator Loss: 1.1676
# Epoch 220/500... Discriminator Loss: 1.2977... Generator Loss: 1.1917
# Epoch 221/500... Discriminator Loss: 1.2748... Generator Loss: 0.9640
# Epoch 222/500... Discriminator Loss: 1.2883... Generator Loss: 0.9563
# Epoch 223/500... Discriminator Loss: 1.0622... Generator Loss: 2.3026
# Epoch 224/500... Discriminator Loss: 1.5668... Generator Loss: 0.9056
# Epoch 225/500... Discriminator Loss: 1.2858... Generator Loss: 1.1039
# Epoch 226/500... Discriminator Loss: 1.4044... Generator Loss: 1.0498
# Epoch 227/500... Discriminator Loss: 1.2953... Generator Loss: 1.0461
# Epoch 228/500... Discriminator Loss: 1.3265... Generator Loss: 0.8945
# Epoch 229/500... Discriminator Loss: 1.3419... Generator Loss: 1.1442
# Epoch 230/500... Discriminator Loss: 1.2880... Generator Loss: 1.0711
# Epoch 231/500... Discriminator Loss: 1.0925... Generator Loss: 1.4269
# Epoch 232/500... Discriminator Loss: 1.3473... Generator Loss: 1.0086
# Epoch 233/500... Discriminator Loss: 1.3778... Generator Loss: 0.8969
# Epoch 234/500... Discriminator Loss: 1.2956... Generator Loss: 0.9340
# Epoch 235/500... Discriminator Loss: 1.4045... Generator Loss: 0.8799
# Epoch 236/500... Discriminator Loss: 1.3261... Generator Loss: 0.9298
# Epoch 237/500... Discriminator Loss: 1.2936... Generator Loss: 1.0153
# Epoch 238/500... Discriminator Loss: 1.2009... Generator Loss: 1.1004
# Epoch 239/500... Discriminator Loss: 1.2075... Generator Loss: 1.1781
# Epoch 240/500... Discriminator Loss: 1.2552... Generator Loss: 1.5434
# Epoch 241/500... Discriminator Loss: 1.2669... Generator Loss: 0.9461
# Epoch 242/500... Discriminator Loss: 1.1919... Generator Loss: 1.0980
# Epoch 243/500... Discriminator Loss: 1.2066... Generator Loss: 0.9992
# Epoch 244/500... Discriminator Loss: 1.4052... Generator Loss: 0.8081
# Epoch 245/500... Discriminator Loss: 1.3224... Generator Loss: 0.8715
# Epoch 246/500... Discriminator Loss: 1.4754... Generator Loss: 0.7634
# Epoch 247/500... Discriminator Loss: 1.2837... Generator Loss: 0.8807
# Epoch 248/500... Discriminator Loss: 1.3446... Generator Loss: 0.9147
# Epoch 249/500... Discriminator Loss: 1.0516... Generator Loss: 1.5692
# Epoch 250/500... Discriminator Loss: 1.3027... Generator Loss: 1.0014
# Epoch 251/500... Discriminator Loss: 1.7520... Generator Loss: 0.7844
# Epoch 252/500... Discriminator Loss: 1.2683... Generator Loss: 1.0920
# Epoch 253/500... Discriminator Loss: 1.4447... Generator Loss: 1.0950
# Epoch 254/500... Discriminator Loss: 1.5010... Generator Loss: 0.8508
# Epoch 255/500... Discriminator Loss: 1.3406... Generator Loss: 0.8885
# Epoch 256/500... Discriminator Loss: 1.3839... Generator Loss: 0.8767
# Epoch 257/500... Discriminator Loss: 1.3457... Generator Loss: 0.8349
# Epoch 258/500... Discriminator Loss: 1.5078... Generator Loss: 0.9075
# Epoch 259/500... Discriminator Loss: 1.2822... Generator Loss: 0.9185
# Epoch 260/500... Discriminator Loss: 1.4135... Generator Loss: 0.9774
# Epoch 261/500... Discriminator Loss: 1.3346... Generator Loss: 1.0959
# Epoch 262/500... Discriminator Loss: 1.2814... Generator Loss: 1.1833
# Epoch 263/500... Discriminator Loss: 1.1662... Generator Loss: 1.3188
# Epoch 264/500... Discriminator Loss: 1.1286... Generator Loss: 1.7049
# Epoch 265/500... Discriminator Loss: 1.3172... Generator Loss: 1.0621
# Epoch 266/500... Discriminator Loss: 1.3802... Generator Loss: 1.1317
# Epoch 267/500... Discriminator Loss: 1.2421... Generator Loss: 1.0375
# Epoch 268/500... Discriminator Loss: 1.3384... Generator Loss: 1.0809
# Epoch 269/500... Discriminator Loss: 1.3499... Generator Loss: 0.9117
# Epoch 270/500... Discriminator Loss: 1.3353... Generator Loss: 0.9094
# Epoch 271/500... Discriminator Loss: 1.3455... Generator Loss: 0.8754
# Epoch 272/500... Discriminator Loss: 1.3068... Generator Loss: 0.9624
# Epoch 273/500... Discriminator Loss: 1.4572... Generator Loss: 0.8266
# Epoch 274/500... Discriminator Loss: 1.3751... Generator Loss: 0.8552
# Epoch 275/500... Discriminator Loss: 1.1464... Generator Loss: 1.3898
# Epoch 276/500... Discriminator Loss: 1.2709... Generator Loss: 1.5469
# Epoch 277/500... Discriminator Loss: 1.2613... Generator Loss: 0.9884
# Epoch 278/500... Discriminator Loss: 1.3330... Generator Loss: 0.9168
# Epoch 279/500... Discriminator Loss: 1.3218... Generator Loss: 0.9459
# Epoch 280/500... Discriminator Loss: 1.3163... Generator Loss: 0.8820
# Epoch 281/500... Discriminator Loss: 1.4572... Generator Loss: 0.8839
# Epoch 282/500... Discriminator Loss: 1.2844... Generator Loss: 1.0501
# Epoch 283/500... Discriminator Loss: 1.1652... Generator Loss: 1.2641
# Epoch 284/500... Discriminator Loss: 1.4531... Generator Loss: 0.9024
# Epoch 285/500... Discriminator Loss: 1.3197... Generator Loss: 1.1036
# Epoch 286/500... Discriminator Loss: 1.3466... Generator Loss: 0.9468
# Epoch 287/500... Discriminator Loss: 1.1848... Generator Loss: 1.4502
# Epoch 288/500... Discriminator Loss: 1.5808... Generator Loss: 0.9517
# Epoch 289/500... Discriminator Loss: 1.3769... Generator Loss: 0.9933
# Epoch 290/500... Discriminator Loss: 1.2775... Generator Loss: 0.9785
# Epoch 291/500... Discriminator Loss: 1.3316... Generator Loss: 0.8759
# Epoch 292/500... Discriminator Loss: 1.3227... Generator Loss: 0.9612
# Epoch 293/500... Discriminator Loss: 1.4415... Generator Loss: 0.9697
# Epoch 294/500... Discriminator Loss: 1.2045... Generator Loss: 1.7150
# Epoch 295/500... Discriminator Loss: 1.2382... Generator Loss: 0.9904
# Epoch 296/500... Discriminator Loss: 1.2921... Generator Loss: 1.0008
# Epoch 297/500... Discriminator Loss: 1.2497... Generator Loss: 0.9707
# Epoch 298/500... Discriminator Loss: 1.3756... Generator Loss: 0.9407
# Epoch 299/500... Discriminator Loss: 1.4216... Generator Loss: 0.9643
# Epoch 300/500... Discriminator Loss: 1.3175... Generator Loss: 1.2653
# Epoch 301/500... Discriminator Loss: 1.4696... Generator Loss: 0.9432
# Epoch 302/500... Discriminator Loss: 1.4604... Generator Loss: 0.8319
# Epoch 303/500... Discriminator Loss: 1.2651... Generator Loss: 1.0342
# Epoch 304/500... Discriminator Loss: 1.3577... Generator Loss: 0.8685
# Epoch 305/500... Discriminator Loss: 1.4156... Generator Loss: 0.8496
# Epoch 306/500... Discriminator Loss: 1.3295... Generator Loss: 0.8539
# Epoch 307/500... Discriminator Loss: 1.6356... Generator Loss: 0.9120
# Epoch 308/500... Discriminator Loss: 1.3443... Generator Loss: 0.9555
# Epoch 309/500... Discriminator Loss: 1.4526... Generator Loss: 0.9398
# Epoch 310/500... Discriminator Loss: 1.3248... Generator Loss: 0.9936
# Epoch 311/500... Discriminator Loss: 1.3257... Generator Loss: 0.9569
# Epoch 312/500... Discriminator Loss: 1.3484... Generator Loss: 0.8902
# Epoch 313/500... Discriminator Loss: 1.3891... Generator Loss: 0.8985
# Epoch 314/500... Discriminator Loss: 1.3499... Generator Loss: 0.9066
# Epoch 315/500... Discriminator Loss: 1.3560... Generator Loss: 0.9048
# Epoch 316/500... Discriminator Loss: 1.3271... Generator Loss: 1.2619
# Epoch 317/500... Discriminator Loss: 1.3229... Generator Loss: 1.0899
# Epoch 318/500... Discriminator Loss: 1.1101... Generator Loss: 1.3073
# Epoch 319/500... Discriminator Loss: 1.2523... Generator Loss: 1.2207
# Epoch 320/500... Discriminator Loss: 1.3093... Generator Loss: 0.8921
# Epoch 321/500... Discriminator Loss: 1.5919... Generator Loss: 0.8022

# %% [markdown]
# ## Training loss
#
# Here we'll check out the training losses for the generator and discriminator.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at images taken while training.

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 1, 7, 3, 2. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs. With bonus optical illusion!

# %%
rows, cols = 15, 8
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# Initial noisy inputs turn into different clothes in the Fashion-MNIST database as it goes through $G$ network.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. We just need to pass in a new latent vector $z$ and we'll get new samples!

# %%
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_z = np.random.uniform(-1.0, 1.0, size=(16, z_size))
    gen_samples = sess.run(
                   generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                   feed_dict={input_z: sample_z})
_ = view_samples(0, [gen_samples])
